# %%
# !pip install --quiet -U langchain langchain_openai tavily-python
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.21-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.3.54)
# Requirement already satisfied: langchain<1.0.0,>=0.3.23 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.3.23)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.11.17-cp313-cp313-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.3.32)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.1.3)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.6.0-cp313-cp313-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.4.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.20.0-cp313-cp313-win_amd64.whl.metadata (74 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (2.10.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet>=1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.0)
# Requirement already satisfied: anyio in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (2.27.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.21-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 35.1 MB/s eta 0:00:00
# Downloading aiohttp-3.11.17-cp313-cp313-win_amd64.whl (437 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.6.0-cp313-cp313-win_amd64.whl (119 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.4.3-cp313-cp313-win_amd64.whl (38 kB)
# Downloading propcache-0.3.1-cp313-cp313-win_amd64.whl (44 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading yarl-1.20.0-cp313-cp313-win_amd64.whl (92 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: typing-inspection, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-community
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.17 aiosignal-1.3.2 dataclasses-json-0.6.7 frozenlist-1.6.0 httpx-sse-0.4.0 langchain-community-0.3.21 marshmallow-3.26.1 multidict-6.4.3 mypy-extensions-1.0.0 propcache-0.3.1 pydantic-settings-2.9.1 typing-inspect-0.9.0 typing-inspection-0.4.0 yarl-1.20.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv() # .env 파일 로드

TAVILY_API = os.environ.get("TAVILY_API")
GOOGLE_API = os.environ.get("GOOGLE_API")

# %%
from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain_openai.chat_models import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults


tools = [TavilySearchResults(max_results=1)]

prompt = hub.pull("hwchase17/openai-functions-agent")

llm = ChatOpenAI(model="gpt-3.5-turbo-1106", streaming=True)

agent = create_openai_functions_agent(llm, tools, prompt)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 7
#       3 from langchain_openai.chat_models import ChatOpenAI
#       4 from langchain_community.tools.tavily_search import TavilySearchResults
# ----> 7 tools = [TavilySearchResults(max_results=1)]
#       9 prompt = hub.pull("hwchase17/openai-functions-agent")
#      11 llm = ChatOpenAI(model="gpt-3.5-turbo-1106", streaming=True)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_community\tools\tavily_search\tool.py:159, in TavilySearchResults.__init__(self, **kwargs)
#     154 if "tavily_api_key" in kwargs:
#     155     kwargs["api_wrapper"] = TavilySearchAPIWrapper(
#     156         tavily_api_key=kwargs["tavily_api_key"]
#     157     )
# --> 159 super().__init__(**kwargs)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\tools\base.py:442, in BaseTool.__init__(self, **kwargs)
#     437     msg = (
#     438         "args_schema must be a subclass of pydantic BaseModel or "
#     439         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     440     )
#     441     raise TypeError(msg)
# --> 442 super().__init__(**kwargs)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python313\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 1 validation error for TavilySearchAPIWrapper
#   Value error, Did not find tavily_api_key, please add an environment variable `TAVILY_API_KEY` which contains it, or pass `tavily_api_key` as a named parameter. [type=value_error, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/value_error

# %%
from typing import TypedDict, Annotated, List, Union
from langchain_core.agents import AgentAction, AgentFinish
from langchain_core.messages import BaseMessage 
import operator


class AgentState(TypedDict) : 
    input : str
    chat_history = list[BaseMessage]
    agent_outcome : Union[AgentAction, AgentFinish, None]
    intermediate_steps : Annotated[List[tuple[AgentAction, str]], operator.add]

# %%
# !pip install langgraph
# Out:
# Collecting langgraph
#   Downloading langgraph-0.3.31-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph) (0.3.54)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.10 (from langgraph)
#   Downloading langgraph_checkpoint-2.0.24-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-prebuilt<0.2,>=0.1.8 (from langgraph)
#   Downloading langgraph_prebuilt-0.1.8-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph)
#   Downloading langgraph_sdk-0.1.61-py3-none-any.whl.metadata (1.8 kB)
# Collecting xxhash<4.0.0,>=3.5.0 (from langgraph)
#   Downloading xxhash-3.5.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (0.3.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4,>=0.1->langgraph) (2.10.4)
# Collecting ormsgpack<2.0.0,>=1.8.0 (from langgraph-checkpoint<3.0.0,>=2.0.10->langgraph)
#   Downloading ormsgpack-1.9.1-cp313-cp313-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10.16)
# Requirement already satisfied: anyio in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (4.8.0)
# Requirement already satisfied: certifi in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.0.7)
# Requirement already satisfied: idna in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.1->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.1->langgraph) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph) (1.3.1)
# Downloading langgraph-0.3.31-py3-none-any.whl (145 kB)
# Downloading langgraph_checkpoint-2.0.24-py3-none-any.whl (42 kB)
# Downloading langgraph_prebuilt-0.1.8-py3-none-any.whl (25 kB)
# Downloading langgraph_sdk-0.1.61-py3-none-any.whl (47 kB)
# Downloading xxhash-3.5.0-cp313-cp313-win_amd64.whl (30 kB)
# Downloading ormsgpack-1.9.1-cp313-cp313-win_amd64.whl (125 kB)
# Installing collected packages: xxhash, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
# Successfully installed langgraph-0.3.31 langgraph-checkpoint-2.0.24 langgraph-prebuilt-0.1.8 langgraph-sdk-0.1.61 ormsgpack-1.9.1 xxhash-3.5.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# define the nodes

#agent node랑 Agetn decision node이렇게 2개 노드가 필요함. 
#edge - 

from langchain_core.agents import AgentFinish
from langgraph.prebuilt.tool_executor import Tool
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 7
#       1 # define the nodes
#       2
#       3 #agent node랑 Agetn decision node이렇게 2개 노드가 필요함.
#       4 #edge -
#       6 from langchain_core.agents import AgentFinish
# ----> 7 from langgraph.prebuilt.tool_executor import Tool
#
# ModuleNotFoundError: No module named 'langgraph.prebuilt.tool_executor'

# %%
# !pip install "langgraph-cli[inmem]"
# Out:
# Collecting langgraph-cli[inmem]
#   Downloading langgraph_cli-0.2.5-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-cli[inmem]) (8.1.8)
# Collecting langgraph-api<0.2.0,>=0.1.0 (from langgraph-cli[inmem])
#   Downloading langgraph_api-0.1.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting langgraph-runtime-inmem<0.1.0,>=0.0.1 (from langgraph-cli[inmem])
#   Downloading langgraph_runtime_inmem-0.0.4-py3-none-any.whl.metadata (665 bytes)
# Requirement already satisfied: python-dotenv>=0.8.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-cli[inmem]) (1.0.1)
# Requirement already satisfied: colorama in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from click<9.0.0,>=8.1.7->langgraph-cli[inmem]) (0.4.6)
# Collecting cloudpickle<4.0.0,>=3.0.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting cryptography<45.0,>=42.0.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.28.1)
# Collecting jsonschema-rs<0.30,>=0.20.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Downloading jsonschema_rs-0.29.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.2.38 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.3.54)
# Requirement already satisfied: langgraph<0.4.0,>=0.2.56 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.3.31)
# Requirement already satisfied: langgraph-checkpoint<3.0,>=2.0.23 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.0.24)
# Requirement already satisfied: langgraph-sdk<0.2.0,>=0.1.61 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.1.61)
# Requirement already satisfied: langsmith<0.4.0,>=0.1.63 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.3.32)
# Requirement already satisfied: orjson>=3.9.7 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (3.10.16)
# Collecting pyjwt<3.0.0,>=2.9.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting sse-starlette<2.2.0,>=2.1.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Downloading sse_starlette-2.1.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: starlette>=0.38.6 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.41.3)
# Collecting structlog<26,>=24.1.0 (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem])
#   Downloading structlog-25.2.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: tenacity>=8.0.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (9.1.2)
# Requirement already satisfied: uvicorn>=0.26.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.34.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.0.3)
# Collecting blockbuster<2.0.0,>=1.5.24 (from langgraph-runtime-inmem<0.1.0,>=0.0.1->langgraph-cli[inmem])
#   Downloading blockbuster-1.5.24-py3-none-any.whl.metadata (10 kB)
# Collecting forbiddenfruit>=0.1.4 (from blockbuster<2.0.0,>=1.5.24->langgraph-runtime-inmem<0.1.0,>=0.0.1->langgraph-cli[inmem])
#   Downloading forbiddenfruit-0.1.4.tar.gz (43 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: cffi>=1.12 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from cryptography<45.0,>=42.0.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.17.1)
# Requirement already satisfied: anyio in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (4.8.0)
# Requirement already satisfied: certifi in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.0.7)
# Requirement already satisfied: idna in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.10.4)
# Requirement already satisfied: langgraph-prebuilt<0.2,>=0.1.8 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph<0.4.0,>=0.2.56->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.1.8)
# Requirement already satisfied: xxhash<4.0.0,>=3.5.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph<0.4.0,>=0.2.56->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (3.5.0)
# Requirement already satisfied: ormsgpack<2.0.0,>=1.8.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<3.0,>=2.0.23->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.9.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4.0,>=0.1.63->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4.0,>=0.1.63->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.4.0,>=0.1.63->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.23.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (1.3.1)
# Requirement already satisfied: pycparser in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12->cryptography<45.0,>=42.0.0->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.22)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4.0,>=0.2.38->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4.0,>=0.1.63->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ssafy\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langsmith<0.4.0,>=0.1.63->langgraph-api<0.2.0,>=0.1.0->langgraph-cli[inmem]) (2.3.0)
# Downloading langgraph_api-0.1.9-py3-none-any.whl (221 kB)
# Downloading langgraph_runtime_inmem-0.0.4-py3-none-any.whl (26 kB)
# Downloading langgraph_cli-0.2.5-py3-none-any.whl (33 kB)
# Downloading blockbuster-1.5.24-py3-none-any.whl (13 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 57.2 MB/s eta 0:00:00
# Downloading jsonschema_rs-0.29.1-cp313-cp313-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 62.1 MB/s eta 0:00:00
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading sse_starlette-2.1.3-py3-none-any.whl (9.4 kB)
# Downloading structlog-25.2.0-py3-none-any.whl (68 kB)
# Building wheels for collected packages: forbiddenfruit
#   Building wheel for forbiddenfruit (pyproject.toml): started
#   Building wheel for forbiddenfruit (pyproject.toml): finished with status 'done'
#   Created wheel for forbiddenfruit: filename=forbiddenfruit-0.1.4-py3-none-any.whl size=21929 sha256=4614a23c9b6c6bab8ba61684817111a734420227bf7a6d12d51f4eebd8861b31
#   Stored in directory: c:\users\ssafy\appdata\local\pip\cache\wheels\24\7f\23\8761105461e8d98c818694d7d698eb070ddda31aea4c928362
# Successfully built forbiddenfruit
# Installing collected packages: forbiddenfruit, structlog, pyjwt, jsonschema-rs, cloudpickle, blockbuster, langgraph-runtime-inmem, langgraph-cli, cryptography, sse-starlette, langgraph-api
# Successfully installed blockbuster-1.5.24 cloudpickle-3.1.1 cryptography-44.0.2 forbiddenfruit-0.1.4 jsonschema-rs-0.29.1 langgraph-api-0.1.9 langgraph-cli-0.2.5 langgraph-runtime-inmem-0.0.4 pyjwt-2.10.1 sse-starlette-2.1.3 structlog-25.2.0
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
